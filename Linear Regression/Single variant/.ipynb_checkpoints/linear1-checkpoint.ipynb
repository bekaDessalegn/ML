# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model

# %%
data = pd.read_csv("./homeprice.csv")
data
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel("Area", fontsize=20)
plt.ylabel("Price", fontsize=20)
plt.scatter(data.area, data.price, color="red", marker="+")
plt.plot(data.area.values, reg.predict(data[['area']]), color="blue")
# Out:
# C:\Users\bekad\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
reg = linear_model.LinearRegression()
reg.fit(data[['area']].values, data.price)
# Out:
# LinearRegression()

# %%
data.price.values
# Out:
# array([550000, 565000, 610000, 680000, 725000], dtype=int64)

# %%
data[['area']].values
# Out:
# array([[2600],
#        [3000],
#        [3200],
#        [3600],
#        [4000]], dtype=int64)

# %%
reg.predict([[3300]])
# Out:
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
test_data = pd.read_csv("./area.csv")

# %%
test_data
# Out:
#    area
# 0  5000
# 1  5200
# 2  6500
# 3  3000
# 4  4500
# 5  4800

# %%
test_data.values
# Out:
# array([[5000],
#        [5200],
#        [6500],
#        [3000],
#        [4500],
#        [4800]], dtype=int64)

# %%
predicted_price = reg.predict(test_data.values)

# %%
predicted_price
# Out:
# array([ 859554.79452055,  886712.32876712, 1063236.30136986,
#         587979.45205479,  791660.95890411,  832397.26027397])

# %%
test_data["prices"] = predicted_price

# %%
test_data
# Out:
#    area        prices
# 0  5000  8.595548e+05
# 1  5200  8.867123e+05
# 2  6500  1.063236e+06
# 3  3000  5.879795e+05
# 4  4500  7.916610e+05
# 5  4800  8.323973e+05

# %%
test_data.to_csv("prediction.csv",index=False)
